# %% [markdown]
# <a href="https://colab.research.google.com/github/yajima-yasutoshi/DataScience2025/blob/main/20260109/%E6%A9%9F%E6%A2%B0%E5%AD%A6%E7%BF%92%E5%B0%8F%E3%83%86%E3%82%B9%E3%83%88%E8%A7%A3%E7%AD%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 小テスト解答

# %% [markdown]
# # 準備

# %% [markdown]
# ## 日本語環境のインストールと必要なライブラリーのインポート

# %%
# 日本語環境のインストール
# !pip install japanize-matplotlib

# 必要なライブラリをインポート
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import japanize_matplotlib

# 必要なライブラリのインポート
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split, GridSearchCV

# 決定木に必要なライブラリー
from sklearn.tree import DecisionTreeClassifier, plot_tree

# ランダムフォレストに必要なライブラリー
from sklearn.ensemble import RandomForestClassifier

# その他必要なライブラリー
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 26.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for japanize-matplotlib: filename=japanize_matplotlib-1.1.3-py3-none-any.whl size=4120257 sha256=b06b7e8e7afa17e6884d3b9560ae76bf2d668788258eed3f9f754412c06f2b65
#   Stored in directory: /root/.cache/pip/wheels/c1/f7/9b/418f19a7b9340fc16e071e89efc379aca68d40238b258df53d
# Successfully built japanize-matplotlib
# ...

# %% [markdown]
# ## Titanic データ

# %%
# データを読み込む
data = sns.load_dataset("titanic") #タイタニックのデータ

# %%
data['embarked'].value_counts()
# Out:
# embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
data.groupby('survived')['fare'].mean()
# Out:
# survived
# 0    22.117887
# 1    48.395408
# Name: fare, dtype: float64

# %%
# 欠損値を埋める
data['age'] = data['age'].fillna(data['age'].mean() )
data['embarked'] = data['embarked'].fillna(data['embarked'].mode()[0] )
data['embark_town'] = data['embark_town'].fillna(data['embark_town'].mode()[0] )

# 説明変数と目的変数を設定
X = data[['age', 'fare', 'sibsp', 'parch']]
y = data['survived']

# 決定木に必要なライブラリー
from sklearn.tree import DecisionTreeClassifier

# 決定木の準備
model = DecisionTreeClassifier(max_depth=2, random_state=25)

# 学習
model.fit(X, y.values.ravel())

# 決定木を可視化する
plt.figure(figsize=(16,7))
plot_tree(model, filled=True, feature_names=X.columns[:-1], class_names=['0(死亡)','1(生存)'])
plt.show()

# %%
# データを読み込む
data = sns.load_dataset("titanic") #タイタニックのデータ

# 欠損値を埋める
data['age'] = data['age'].fillna(data['age'].mean() )
data['embarked'] = data['embarked'].fillna(data['embarked'].mode()[0] )
data['embark_town'] = data['embark_town'].fillna(data['embark_town'].mode()[0] )

# 説明変数と目的変数を設定
X = data[['age', 'fare', 'sibsp', 'parch']]
y = data['survived']

# 決定木に必要なライブラリー
from sklearn.tree import DecisionTreeClassifier

# 決定木の準備
model = DecisionTreeClassifier(max_depth=3, random_state=25)

# 学習
model.fit(X, y.values.ravel())

# 決定木を可視化する
plt.figure(figsize=(16,8))
plot_tree(model, filled=True, feature_names=X.columns[:-1], class_names=['0(死亡)','1(生存)'])
plt.show()

# %% [markdown]
# #【参考】詳しい説明が書かれたサイト
#
# 各モジュールの詳しい使い方は以下のサイトに記載されている。
#
# * 決定木 https://scikit-learn.org/stable/api/sklearn.tree.html
#
# * ランダムフォレスト
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
